# %%
import pandas as pd
data = pd.read_csv('diabetes.csv')
x = data.drop("Outcome", axis=1)
y = data["Outcome"]
# Link https://www.analyticsvidhya.com/blog/2021/05/develop-your-first-deep-learning-model-in-python-with-keras/

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(12, input_dim=8, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy", optimizer="sgd", metrics=["accuracy"])

# %%
model.fit(x,y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 0s 822us/step - loss: 0.6059 - accuracy: 0.6862
# Epoch 2/150
# 77/77 [==============================] - 0s 844us/step - loss: 0.6076 - accuracy: 0.6901
# Epoch 3/150
# 77/77 [==============================] - 0s 880us/step - loss: 0.6102 - accuracy: 0.6953
# Epoch 4/150
# 77/77 [==============================] - 0s 868us/step - loss: 0.6071 - accuracy: 0.6940
# Epoch 5/150
# 77/77 [==============================] - 0s 790us/step - loss: 0.6015 - accuracy: 0.6966
# Epoch 6/150
# 77/77 [==============================] - 0s 803us/step - loss: 0.6095 - accuracy: 0.6888
# Epoch 7/150
# 77/77 [==============================] - 0s 829us/step - loss: 0.6045 - accuracy: 0.6953
# Epoch 8/150
# 77/77 [==============================] - 0s 816us/step - loss: 0.6086 - accuracy: 0.6862
# Epoch 9/150
# 77/77 [==============================] - 0s 764us/step - loss: 0.6035 - accuracy: 0.7031
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(x, y)
print("Model accuracy: %.2f"% (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5867 - accuracy: 0.7057
# Model accuracy: 70.57

# %%
predictions = model.predict(x)
#print([round(x[0]) for x in predictions])

# %%
model = Sequential()  #define model
model.add(Dense(12, input_dim=8, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy", optimizer="sgd", metrics=["accuracy"]) #compile model
model.fit(x,y, epochs=150, batch_size=10,verbose=0)  #training - verbose=0 takes off the epochs printed
_, accuracy = model.evaluate(x,y)    #testing
print("Model accuracy: %.2f"% (accuracy*100))
predictions = model.predict(x)     #make predictions
#round the prediction
rounded = [round(x[0]) for x in predictions]
# Out:
# 24/24 [==============================] - 0s 748us/step - loss: 0.5702 - accuracy: 0.6927
# Model accuracy: 69.27
